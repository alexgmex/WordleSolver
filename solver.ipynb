# %% [markdown]
# **Analyse Letter Frequency and Create Word Dict**

# %%
import copy
import string

counter_dict = {letter: 0 for letter in string.ascii_lowercase}
position_dict = {pos: copy.deepcopy(counter_dict) for pos in range(5)}
words_dict = {}

with open("words.txt", "r") as file:
    for word in file:
        word = word.strip()
        words_dict[word] = 0
        for pos, letter in enumerate(word):
            counter_dict[letter] += 1
            position_dict[pos][letter] += 1

total_letters = sum(counter_dict.values())

for letter in counter_dict:
    counter_dict[letter] = round(((counter_dict[letter]/total_letters))*100, 2)
for pos in position_dict:
    for letter in position_dict[pos]:
        position_dict[pos][letter] = round((position_dict[pos][letter]/(total_letters/5))*100, 2)

print(counter_dict)
print(position_dict)
# Out:
# {'a': 9.6, 'b': 2.49, 'c': 3.02, 'd': 3.68, 'e': 10.04, 'f': 1.67, 'g': 2.51, 'h': 2.68, 'i': 5.9, 'j': 0.46, 'k': 2.36, 'l': 5.09, 'm': 3.25, 'n': 4.68, 'o': 7.02, 'p': 3.28, 'q': 0.2, 'r': 6.35, 's': 9.85, 't': 4.99, 'u': 3.94, 'v': 1.08, 'w': 1.52, 'x': 0.44, 'y': 3.23, 'z': 0.68}
# {0: {'a': 5.84, 'b': 6.75, 'c': 6.53, 'd': 4.95, 'e': 2.22, 'f': 4.35, 'g': 4.61, 'h': 3.58, 'i': 1.21, 'j': 1.51, 'k': 2.89, 'l': 4.21, 'm': 6.4, 'n': 3.15, 'o': 2.37, 'p': 7.61, 'q': 0.69, 'r': 5.35, 's': 11.22, 't': 5.94, 'u': 1.46, 'v': 1.91, 'w': 2.92, 'x': 0.12, 'y': 1.38, 'z': 0.82}, 1: {'a': 18.05, 'b': 0.73, 'c': 1.39, 'd': 0.73, 'e': 12.5, 'f': 0.25, 'g': 0.63, 'h': 4.07, 'i': 10.76, 'j': 0.09, 'k': 0.77, 'l': 5.21, 'm': 1.42, 'n': 2.61, 'o': 16.25, 'p': 1.68, 'q': 0.11, 'r': 6.86, 's': 0.76, 't': 1.72, 'u': 9.21, 'v': 0.38, 'w': 1.19, 'x': 0.42, 'y': 2.01, 'z': 0.2}, 2: {'a': 9.25, 'b': 2.6, 'c': 3.14, 'd': 3.14, 'e': 6.72, 'f': 1.37, 'g': 2.87, 'h': 0.98, 'i': 7.9, 'j': 0.4, 'k': 2.21, 'l': 6.55, 'm': 3.9, 'n': 7.53, 'o': 7.49, 'p': 2.87, 'q': 0.12, 'r': 9.11, 's': 4.13, 't': 4.95, 'u': 5.08, 'v': 1.87, 'w': 2.05, 'x': 0.98, 'y': 1.66, 'z': 1.11}, 3: {'a': 8.88, 'b': 1.9, 'c': 3.07, 'd': 3.71, 'e': 17.04, 'f': 1.74, 'g': 3.28, 'h': 1.91, 'i': 7.05, 'j': 0.28, 'k': 3.84, 'l': 5.85, 'm': 3.0, 'n': 5.96, 'o': 5.57, 'p': 3.14, 'q': 0.02, 'r': 5.45, 's': 3.96, 't': 6.99, 'u': 3.31, 'v': 1.19, 'w': 0.96, 'x': 0.1, 'y': 0.83, 'z': 0.98}, 4: {'a': 5.96, 'b': 0.47, 'c': 0.98, 'd': 5.88, 'e': 11.71, 'f': 0.64, 'g': 1.15, 'h': 2.88, 'i': 2.57, 'j': 0.02, 'k': 2.09, 'l': 3.63, 'm': 1.53, 'n': 4.16, 'o': 3.41, 'p': 1.11, 'q': 0.03, 'r': 4.96, 's': 29.21, 't': 5.35, 'u': 0.65, 'v': 0.03, 'w': 0.46, 'x': 0.57, 'y': 10.28, 'z': 0.28}}

# %% [markdown]
# **Reset Word Dict**

# %%
for word in words_dict:
    words_dict[word] = 0
    for pos, letter in enumerate(word):
        words_dict[word] += counter_dict[letter]*position_dict[pos][letter]
    words_dict[word] = round(words_dict[word], 2)

words_dict = dict(sorted(words_dict.items(), key=lambda item: item[1], reverse=True))
print(words_dict)
# Out:
# {'sanes': 777.84, 'sales': 775.94, 'sates': 767.3, 'sames': 755.27, 'sades': 754.15, 'seres': 752.67, 'sages': 749.8, 'sabes': 749.07, 'sakes': 747.81, 'safes': 744.88, 'saves': 744.62, 'sazes': 743.35, 'saxes': 743.03, 'sores': 741.24, 'senes': 730.06, 'seles': 728.16, 'rares': 723.9, 'tares': 719.57, 'sones': 718.63, 'soles': 716.73, 'pares': 714.89, 'lares': 711.36, 'mares': 710.73, 'cares': 709.65, 'dares': 708.14, 'semes': 707.49, 'bares': 706.74, 'rases': 706.73, 'sedes': 706.37, 'nares': 704.67, 'tases': 702.4, 'gares': 701.5, 'ranes': 701.29, 'hares': 699.52, 'rales': 699.39, 'pases': 697.72, 'fares': 697.19, 'sezes': 695.57, 'sexes': 695.25, 'tales': 695.06, 'eases': 695.05, 'wares': 694.37, 'lases': 694.19, 'mases': 693.56, 'soces': 692.87, 'cases': 692.48, 'panes': 692.28, 'vares': 691.99, 'rates': 690.75, 'sires': 690.65, 'pales': 690.38, 'salas': 690.1, 'bases': 689.57, 'oases': 689.4, 'lanes': 688.75, 'sokes': 688.61, 'manes': 688.12, 'eales': 687.71, 'canes': 687.04, 'tates': 686.42, 'males': 686.22, 'kaies': 685.51, 'slaes': 684.64, 'gases': 684.33, 'banes': 684.13, 'soxes': 683.82, 'dales': 683.64, 'bales': 682.23, 'pates': 681.74, 'rames': 678.73, 'mates': 677.58, 'wases': 677.2, 'gales': 676.99, 'cates': 676.5, 'races': 675.54, 'rapes': 675.47, 'hales': 675.01, 'dates': 675.0, 'vases': 674.82, 'fanes': 674.59, 'tames': 674.4, 'kanes': 674.14, 'bates': 673.59, 'sises': 673.48, 'rages': 673.26, 'fales': 672.68, 'kales': 672.24, 'teres': 671.79, 'wanes': 671.76, 'nates': 671.52, 'rakes': 671.27, 'taces': 671.2, 'tapes': 671.13, 'saris': 670.96, 'yales': 669.88, 'wales': 669.86, 'samas': 669.44, 'vanes': 669.38, 'saags': 668.55, 'saros': 668.47, 'gates': 668.35, 'tabes': 668.19, 'raves': 668.07, 'sines': 668.04, 'janes': 668.02, 'vales': 667.48, 'peres': 667.11, 'takes': 666.94, 'razes': 666.81, 'paces': 666.52, 'raxes': 666.48, 'papes': 666.45, 'hates': 666.38, 'rajes': 666.24, 'lames': 666.18, 'siles': 666.14, 'lades': 665.06, 'rores': 664.7, 'cames': 664.48, 'pages': 664.24, 'fates': 664.05, 'sagas': 663.97, 'spaes': 663.63, 'leres': 663.58, 'sures': 663.45, 'cades': 663.36, 'laces': 662.99, 'dames': 662.97, 'meres': 662.95, 'maces': 662.36, 'mapes': 662.29, 'taxes': 662.15, 'sayas': 662.13, 'tajes': 661.9, 'ceres': 661.87, 'yates': 661.24, 'capes': 661.21, 'deres': 660.36, 'tores': 660.36, 'mages': 660.08, 'daces': 659.78, 'names': 659.5, 'mabes': 659.35, 'paves': 659.06, 'cages': 659.0, 'beres': 658.96, 'reses': 658.95, 'lakes': 658.72, 'makes': 658.1, 'sites': 657.5, 'paxes': 657.47, 'cakes': 657.02, 'eaves': 656.39, 'games': 656.33, 'napes': 656.24, 'pores': 655.68, 'laves': 655.53, 'soras': 655.41, 'babes': 655.36, 'gades': 655.21, 'hames': 654.35, 'lazes': 654.26, 'bayes': 654.25, 'bakes': 654.1, 'cafes': 654.09, 'nages': 654.03, 'laxes': 653.94, 'caves': 653.82, 'geres': 653.72, 'mazes': 653.63, 'maxes': 653.31, 'nabes': 653.3, 'hades': 653.23, 'gapes': 653.06, 'sairs': 652.73, 'lores': 652.15, 'fames': 652.02, 'aedes': 651.92, 'heres': 651.74, 'kames': 651.58, 'mores': 651.52, 'dazes': 651.05, 'fades': 650.9, 'gages': 650.85, 'oaves': 650.74, 'kades': 650.46, 'cores': 650.44, 'feres': 649.41, 'wames': 649.19, 'tenes': 649.18, 'snees': 649.0, 'dores': 648.94, 'naves': 648.84, 'faces': 648.83, 'sloes': 648.42, 'wades': 648.07, 'sails': 647.9, 'nazes': 647.58, 'bores': 647.53, 'roses': 647.53, 'seats': 647.42, 'teles': 647.28, 'sears': 647.14, 'hakes': 646.89, 'salis': 646.45, 'leses': 646.41, 'suses': 646.28, 'sains': 646.02, 'meses': 645.78, 'vades': 645.7, 'james': 645.45, 'fakes': 644.56, 'penes': 644.5, 'gazes': 644.41, 'sides': 644.36, 'jades': 644.33, 'senas': 644.22, 'yages': 643.74, 'wages': 643.72, 'haves': 643.69, 'vapes': 643.56, 'toses': 643.2, 'sards': 643.02, 'peles': 642.6, 'hazes': 642.43, 'sarus': 642.41, 'seals': 642.31, 'gores': 642.29, 'sices': 642.28, 'sipes': 642.21, 'japes': 642.19, 'rones': 642.09, 'hajes': 641.86, 'beses': 641.79, 'wakes': 641.73, 'sants': 641.64, 'smees': 641.4 ...

# %% [markdown]
# **Solve**

# %%
for guess_num in range(7):
    guess = input(f"Suggested guesses: {list(words_dict.keys())[:5]}. What was your guess?").lower()
    if guess == "quit":
        break
    results = input("What was the result of the guess?\nUse \"x\" for grey, \"y\" for yellow and \"g\" for green!").lower()

    # Check multiples
    info_dict = {}
    for pos, letter in enumerate(guess):
        if letter in info_dict:
            info_dict[letter].append((pos, results[pos]))
        else:
            info_dict[letter] = [(pos, results[pos])]
    
    # Process
    for letter in info_dict:
        # If there was only one letter in that guess
        if len(info_dict[letter]) == 1:

            # If it was a grey
            if info_dict[letter][0][1] == "x":
                for word in list(words_dict.keys()):
                    if letter in word:
                        del words_dict[word]
            
            # If it was a yellow
            elif info_dict[letter][0][1] == "y":
                for word in list(words_dict.keys()):
                    if letter not in word or word[info_dict[letter][0][0]] == letter:
                        del words_dict[word]

            # If it was a green
            elif info_dict[letter][0][1] == "g":
                for word in list(words_dict.keys()):
                    if word[info_dict[letter][0][0]] != letter:
                        del words_dict[word]

        else:
            
            grey_count = 0
            appearances = len(info_dict[letter])

            for _, result in info_dict[letter]:
                if result == "x":
                    grey_count += 1
            
            for word in list(words_dict.keys()):
                if grey_count != 0:
                    if word.count(letter) != (appearances - grey_count):
                        del words_dict[word]
                else:
                    if word.count(letter) < appearances:
                        del words_dict[word]
            
            for pos, result in info_dict[letter]:
                if result == "y":
                    for word in list(words_dict.keys()):
                        if letter not in word or word[pos] == letter:
                            del words_dict[word]
                
                if result == "g":
                    for word in list(words_dict.keys()):
                        if word[pos] != letter:
                            del words_dict[word]
